# %% [markdown]
# <a href="https://colab.research.google.com/github/Kurihararyder/115-1/blob/main/411414973.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello\nHello")
# Out:
# Hello
# Hello

# %%
print("2026","09",sep="/")
# Out:
# 2026/09

# %%
a=5
b=10
c="python"
print(type(c))
# Out:
# <class 'str'>

# %%
x=20
y=30
temp=x
x=y
y=temp
print(x,y)
# Out:
# 30 20

# %%
rate = 1.5 / 100
honkin = float(input("請輸入你的本金 ："))
n = float(input("請輸入幾年後的本金 ："))
honkinwa = honkin*((1 + rate)**n)
print(honkinwa)
# Out:
# 請輸入你的本金 ：50000
# 請輸入幾年後的本金 ：5
# 53864.20019421873
