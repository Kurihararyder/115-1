# %% [markdown]
# <a href="https://colab.research.google.com/github/Kurihararyder/115-1/blob/main/411414973_H2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=20
b=10
print("{}\n{}".format(a,b))
# Out:
# 20
# 10

# %%
c=20
d=10
print("{1}\n{0}".format(c,d))
# Out:
# 10
# 20

# %%
e=114.529
print("{:.2f}".format(e))
# Out:
# 114.53

# %%
k=int(input("只能輸入整數"))
l=float(input("只能輸入浮點數"))
print(type(k))
print(type(l))
# Out:
# 只能輸入整數500
# 只能輸入浮點數25.3
# <class 'int'>
# <class 'float'>

# %%
m=int(input("請輸入目前金幣數量: "))
n=int(input("請輸入獲得金幣數量: "))
o=m+n
print(f"任務完成！你現在有{o}枚金幣",)
# Out:
# 請輸入目前金幣數量: 500
# 請輸入獲得金幣數量: 250
# 任務完成！你現在有750枚金幣
